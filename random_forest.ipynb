# %%
import pandas as pd
import numpy as np
from sklearn.datasets import make_moons
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x,y=make_moons(n_samples=1000,noise=0.2)

# %%
df={'X1':x[:,0],'X2':x[:,1],'y':y}
dataset=pd.DataFrame(df)

# %%
dataset
# Out:
#            X1        X2  y
# 0    1.145328  0.714405  0
# 1    2.234509  0.145884  1
# 2    0.195395  0.787089  0
# 3    1.664217  0.159793  1
# 4    0.139746  1.043550  0
# ..        ...       ... ..
# 995 -0.594894  0.477291  0
# 996  1.839861  0.113951  1
# 997 -0.129232  0.042905  1
# 998  0.272601  0.809750  0
# 999  0.062874 -0.115069  1
#
# [1000 rows x 3 columns]

# %%
sns.scatterplot(x='X1',y='X2',data=dataset,hue='y')
plt.show()

# %%
x_1=dataset.iloc[:,:-1]
y_1=dataset['y']

# %%
x_train,x_test,y_train,y_test=train_test_split(x_1, y_1, test_size=0.3, random_state=None)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc=RandomForestClassifier(n_estimators=500)

# %%
rfc.fit(x_train, y_train)
# Out:
# RandomForestClassifier(n_estimators=500)

# %%
rfc.score(x_train, y_train)*100 , rfc.score(x_test, y_test)*100
# Out:
# (100.0, 96.0)
